# %% [markdown]
# ####**Persian word cloud**

# %%
# !pip install PyPDF2 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.2 MB/s eta 0:00:00

# %%
# !pip install hazm -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 892.6/892.6 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 40.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 46.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 30.4 MB/s eta 0:00:00
#   Building wheel for flashtext (setup.py) ... done

# %%
import PyPDF2
import matplotlib.pyplot as ptl
import wordcloud
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def read_pdf(file_path):
    # Open the PDF file in binary mode
    with open(file_path, 'rb') as file:
        # Create a PDF reader object
        pdf_reader = PyPDF2.PdfReader(file)

        # Get the number of pages in the PDF
        num_pages = len(pdf_reader.pages)

        # Extracted text from all pages
        extracted_text = ""

        # Iterate through all pages and append text
        for page_num in range(num_pages):
            # Get the page object
            page = pdf_reader.pages[page_num]

            # Extract text from the page
            text = page.extract_text()

            # Append the text from each page
            extracted_text += text

        return extracted_text

# Replace 'your_file.pdf' with the path to your PDF file
corpus = read_pdf('/content/sample_data/persian.pdf')

# Tokenize the text using nltk.sent_tokenize
sentences = nltk.sent_tokenize(corpus)

# Print each sentence
for sentence in sentences:
    print(sentence)
# Out:
# یک روز زمستانی سرد و برفی بود.
# دخترکی به نام سارا در حال بازی در باغ برف بود.
# برف به آرامی روی زمین فرا گرفته بود و
# درختان با یک لباس سفید شگفتانگیز پوشیده شده بودند .
# سارا با دستانش برف را جمع کرده و یک بندق ساخت.
# او بندق جدیدش را به دلخواه تزئین کرد و دوستانش را به بازی در برف
# دعوت کرد.
# دختران و پسران از اطراف هم گرد آمده و شروع به ساخت اشکال فانتزی از برف کردند.
# باغ برف به سرعت پر از اشکال جالب و زیبا شد.
# سارا و دوستانش لحظات شادی را در میان برف سپری کردند.
# آنها از لحظات
# دوستی و خندهها لذت بردند و هرکس سعی داشت تا اشکال جدیدی از برف بسازد .
# در پایان روز، آفتاب غرب آسمان را با رنگهای زرد و نارنجی رنگ کرد.
# دخترک ان با احساس خستگی از بازی در برف به
# خانههایشان بازگشتند.
# سارا با یادآوری لحظات خوش در باغ برف، با لبخند به خواب رفت تا روز بعد دوباره با دوستانش در دنیای
# سفید برفی بازی کند.

# %%
words=nltk.word_tokenize(corpus.lower())

print(words)
# Out:
# ['یک', 'روز', 'زمستانی', 'سرد', 'و', 'برفی', 'بود', '.', 'دخترکی', 'به', 'نام', 'سارا', 'در', 'حال', 'بازی', 'در', 'باغ', 'برف', 'بود', '.', 'برف', 'به', 'آرامی', 'روی', 'زمین', 'فرا', 'گرفته', 'بود', 'و', 'درختان', 'با', 'یک', 'لباس', 'سفید', 'شگفتانگیز', 'پوشیده', 'شده', 'بودند', '.', 'سارا', 'با', 'دستانش', 'برف', 'را', 'جمع', 'کرده', 'و', 'یک', 'بندق', 'ساخت', '.', 'او', 'بندق', 'جدیدش', 'را', 'به', 'دلخواه', 'تزئین', 'کرد', 'و', 'دوستانش', 'را', 'به', 'بازی', 'در', 'برف', 'دعوت', 'کرد', '.', 'دختران', 'و', 'پسران', 'از', 'اطراف', 'هم', 'گرد', 'آمده', 'و', 'شروع', 'به', 'ساخت', 'اشکال', 'فانتزی', 'از', 'برف', 'کردند', '.', 'باغ', 'برف', 'به', 'سرعت', 'پر', 'از', 'اشکال', 'جالب', 'و', 'زیبا', 'شد', '.', 'سارا', 'و', 'دوستانش', 'لحظات', 'شادی', 'را', 'در', 'میان', 'برف', 'سپری', 'کردند', '.', 'آنها', 'از', 'لحظات', 'دوستی', 'و', 'خندهها', 'لذت', 'بردند', 'و', 'هرکس', 'سعی', 'داشت', 'تا', 'اشکال', 'جدیدی', 'از', 'برف', 'بسازد', '.', 'در', 'پایان', 'روز،', 'آفتاب', 'غرب', 'آسمان', 'را', 'با', 'رنگهای', 'زرد', 'و', 'نارنجی', 'رنگ', 'کرد', '.', 'دخترک', 'ان', 'با', 'احساس', 'خستگی', 'از', 'بازی', 'در', 'برف', 'به', 'خانههایشان', 'بازگشتند', '.', 'سارا', 'با', 'یادآوری', 'لحظات', 'خوش', 'در', 'باغ', 'برف،', 'با', 'لبخند', 'به', 'خواب', 'رفت', 'تا', 'روز', 'بعد', 'دوباره', 'با', 'دوستانش', 'در', 'دنیای', 'سفید', 'برفی', 'بازی', 'کند', '.']

# %%
# remove punctuation from each word
words=[word.lower() for word in words if word.isalpha()]
words
# Out:
# ['یک',
#  'روز',
#  'زمستانی',
#  'سرد',
#  'و',
#  'برفی',
#  'بود',
#  'دخترکی',
#  'به',
#  'نام',
#  'سارا',
#  'در',
#  'حال',
#  'بازی',
#  'در',
#  'باغ',
#  'برف',
#  'بود',
#  'برف',
#  'به',
#  'آرامی',
#  'روی',
#  'زمین',
#  'فرا',
#  'گرفته',
#  'بود',
#  'و',
#  'درختان',
#  'با',
#  'یک',
#  'لباس',
#  'سفید',
#  'شگفتانگیز',
#  'پوشیده',
#  'شده',
#  'بودند',
#  'سارا',
#  'با',
#  'دستانش',
#  'برف',
#  'را',
#  'جمع',
#  'کرده',
#  'و',
#  'یک',
#  'بندق',
#  'ساخت',
#  'او',
#  'بندق',
#  'جدیدش',
#  'را',
#  'به',
#  'دلخواه',
#  'تزئین',
#  'کرد',
#  'و',
#  'دوستانش',
#  'را',
#  'به',
#  'بازی',
#  'در',
#  'برف',
#  'دعوت',
#  'کرد',
#  'دختران',
#  'و',
#  'پسران',
#  'از',
#  'اطراف',
#  'هم',
#  'گرد',
#  'آمده',
#  'و',
#  'شروع',
#  'به',
#  'ساخت',
#  'اشکال',
#  'فانتزی',
#  'از',
#  'برف',
#  'کردند',
#  'باغ',
#  'برف',
#  'به',
#  'سرعت',
#  'پر',
#  'از',
#  'اشکال',
#  'جالب',
#  'و',
#  'زیبا',
#  'شد',
#  'سارا',
#  'و',
#  'دوستانش',
#  'لحظات',
#  'شادی',
#  'را',
#  'در',
#  'میان',
#  'برف',
#  'سپری',
#  'کردند',
#  'آنها',
#  'از',
#  'لحظات',
#  'دوستی',
#  'و',
#  'خندهها',
#  'لذت',
#  'بردند',
#  'و',
#  'هرکس',
#  'سعی',
#  'داشت',
#  'تا',
#  'اشکال',
#  'جدیدی',
#  'از',
#  'برف',
#  'بسازد',
#  'در',
#  'پایان',
#  'آفتاب',
#  'غرب',
#  'آسمان',
#  'را',
#  'با',
#  'رنگهای',
#  'زرد',
#  'و',
#  'نارنجی',
#  'رنگ',
#  'کرد',
#  'دخترک',
#  'ان',
#  'با',
#  'احساس',
#  'خستگی',
#  'از',
#  'بازی',
#  'در',
#  'برف',
#  'به',
#  'خانههایشان',
#  'بازگشتند',
#  'سارا',
#  'با',
#  'یادآوری',
#  'لحظات',
#  'خوش',
#  'در',
#  'باغ',
#  'با',
#  'لبخند',
#  'به',
#  'خواب',
#  'رفت',
#  'تا',
#  'روز',
#  'بعد',
#  'دوباره',
#  'با',
#  'دوستانش',
#  'در',
#  'دنیای',
#  'سفید',
#  'برفی',
#  'بازی',
#  'کند']

# %%
from hazm import stopwords_list

# Get the list of Persian stopwords from hazm
stop_words = set(stopwords_list())

# Filter out stopwords
filtered_sentence = [w for w in words if w not in stop_words]

# Print the filtered sentence
print(filtered_sentence)
# Out:
# ['روز', 'زمستانی', 'سرد', 'برفی', 'دخترکی', 'نام', 'سارا', 'بازی', 'باغ', 'برف', 'برف', 'آرامی', 'زمین', 'فرا', 'درختان', 'لباس', 'سفید', 'شگفتانگیز', 'پوشیده', 'سارا', 'دستانش', 'برف', 'بندق', 'ساخت', 'بندق', 'جدیدش', 'دلخواه', 'تزئین', 'دوستانش', 'بازی', 'برف', 'دعوت', 'دختران', 'پسران', 'اطراف', 'گرد', 'ساخت', 'اشکال', 'فانتزی', 'برف', 'باغ', 'برف', 'سرعت', 'اشکال', 'جالب', 'زیبا', 'سارا', 'دوستانش', 'لحظات', 'شادی', 'برف', 'سپری', 'لحظات', 'دوستی', 'خندهها', 'لذت', 'بردند', 'هرکس', 'اشکال', 'جدیدی', 'برف', 'بسازد', 'پایان', 'آفتاب', 'غرب', 'آسمان', 'رنگهای', 'زرد', 'نارنجی', 'رنگ', 'دخترک', 'ان', 'احساس', 'خستگی', 'بازی', 'برف', 'خانههایشان', 'بازگشتند', 'سارا', 'یادآوری', 'لحظات', 'خوش', 'باغ', 'لبخند', 'خواب', 'روز', 'دوستانش', 'دنیای', 'سفید', 'برفی', 'بازی']

# %%
from hazm import Lemmatizer

# Create a lemmatizer for Persian
lemmatizer = Lemmatizer()

# Lemmatize the Persian words
lemmatized_words = [lemmatizer.lemmatize(w) for w in filtered_sentence]

# Print the lemmatized words
print(lemmatized_words)
# Out:
# ['روز', 'زمستانی', 'سرد', 'برفی', 'دخترک', 'نام', 'سارا', 'بازی', 'باغ', 'برف', 'برف', 'آرامی', 'زمین', 'فرا', 'درختان', 'لباس', 'سفید', 'شگفتانگیز', 'پوشیده', 'سارا', 'دستان', 'برف', 'بندق', 'ساخت', 'بندق', 'جدید', 'دلخواه', 'تزئین', 'دوستان', 'بازی', 'برف', 'دعوت', 'دخ', 'پسر', 'اطراف', 'گرد', 'ساخت', 'اشکال', 'فانتزی', 'برف', 'باغ', 'برف', 'سرعت', 'اشکال', 'جالب', 'زیبا', 'سارا', 'دوستان', 'لحظات', 'شادی', 'برف', 'سپری', 'لحظات', 'دوستی', 'خنده', 'لذت', 'برد#بر', 'هرکس', 'اشکال', 'جدیدی', 'برف', 'ساخت#ساز', 'پایان', 'آفتاب', 'غرب', 'آسمان', 'رنگ', 'زرد', 'نارنجی', 'رنگ', 'دخترک', 'ان', 'احساس', 'خستگی', 'بازی', 'برف', 'خانه', 'بازگشت#بازگرد', 'سارا', 'یادآوری', 'لحظات', 'خوش', 'باغ', 'لبخند', 'خواب', 'روز', 'دوستان', 'دنیای', 'سفید', 'برفی', 'بازی']

# %%
from hazm import Stemmer

# Create a stemming object for Persian
stemmer = Stemmer()

# Stem the Persian words
stemmed_words = [stemmer.stem(w) for w in filtered_sentence]

# Print the stemmed words
print(stemmed_words)
# Out:
# ['روز', 'زمستان', 'سرد', 'برف', 'دخترک', 'نا', 'سارا', 'باز', 'باغ', 'برف', 'برف', 'آرام', 'زمین', 'فرا', 'درخ', 'لباس', 'سفید', 'شگفتانگیز', 'پوشیده', 'سارا', 'دستان', 'برف', 'بندق', 'ساخ', 'بندق', 'جدید', 'دلخواه', 'تزئین', 'دوستان', 'باز', 'برف', 'دعو', 'دخ', 'پسر', 'اطراف', 'گرد', 'ساخ', 'اشکال', 'فانتز', 'برف', 'باغ', 'برف', 'سرع', 'اشکال', 'جالب', 'زیبا', 'سارا', 'دوستان', 'لحظ', 'شاد', 'برف', 'سپر', 'لحظ', 'دوست', 'خنده', 'لذ', 'بردند', 'هرکس', 'اشکال', 'جدید', 'برف', 'بسازد', 'پا', 'آفتاب', 'غرب', 'آس', 'رنگ', 'زرد', 'نارنج', 'رنگ', 'دخترک', '', 'احساس', 'خستگ', 'باز', 'برف', 'خانه', 'بازگشتند', 'سارا', 'یادآور', 'لحظ', 'خو', 'باغ', 'لبخند', 'خواب', 'روز', 'دوستان', 'دنیا', 'سفید', 'برف', 'باز']

# %%
from hazm import word_tokenize

# Join the list of words into a string
corpus = ' '.join(stemmed_words)

# Tokenize the Persian text
words = word_tokenize(corpus)

# Create a dictionary for frequency distribution
frequency_dist = {}

# Count the occurrences of each word
for word in words:
    frequency_dist[word] = frequency_dist.get(word, 0) + 1

# Filter out short words (length > 3)
large_words = {k: v for k, v in frequency_dist.items() if len(k) > 3}

# Print the frequency distribution for larger Persian words
print(large_words)
# Out:
# {'زمستان': 1, 'دخترک': 2, 'سارا': 4, 'آرام': 1, 'زمین': 1, 'لباس': 1, 'سفید': 2, 'شگفتانگیز': 1, 'پوشیده': 1, 'دستان': 1, 'بندق': 2, 'جدید': 2, 'دلخواه': 1, 'تزئین': 1, 'دوستان': 3, 'اطراف': 1, 'اشکال': 3, 'فانتز': 1, 'جالب': 1, 'زیبا': 1, 'دوست': 1, 'خنده': 1, 'بردند': 1, 'هرکس': 1, 'بسازد': 1, 'آفتاب': 1, 'نارنج': 1, 'احساس': 1, 'خستگ': 1, 'خانه': 1, 'بازگشتند': 1, 'یادآور': 1, 'لبخند': 1, 'خواب': 1, 'دنیا': 1}

# %%
frequency_dist = nltk.FreqDist(large_words)
frequency_dist
frequency_dist.plot(30,cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
# !pip install persian_wordcloud -q

# %%
from persian_wordcloud.wordcloud import PersianWordCloud
import matplotlib.pyplot as plt

# Create a PersianWordCloud object
wordcloud = PersianWordCloud(width=1000, height=500, background_color='white').generate_from_frequencies(large_words)

# Plot the Persian WordCloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Persian Word Cloud for Frequency Distribution of Larger Persian Words')
plt.show()
